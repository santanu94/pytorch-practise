# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Colab\ Notebooks/Question\ Tagging
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/Question Tagging

# %%
import pandas as pd
import pickle
import bs4 as bs
import re

K = 20

# %%
questions = pd.read_csv('StackSample/Questions.csv', encoding='latin_1')
print('Shape -', questions.shape)
questions.head(2)
# Out:
# Shape - (1264216, 7)
#    Id  ...                                               Body
# 0  80  ...  <p>I've written a database generation script i...
# 1  90  ...  <p>Are there any really good tutorials explain...
#
# [2 rows x 7 columns]

# %%
tags = pd.read_csv('StackSample/Tags.csv')
print('Shape -', tags.shape)
tags.head(2)
# Out:
# Shape - (3750994, 2)
#    Id             Tag
# 0  80            flex
# 1  80  actionscript-3

# %% [markdown]
# ###Merge Datasets on Top K tags

# %%
tags['Tag'] = tags['Tag'].apply(lambda x: re.sub('-', ' ', str(x)))
tags.head(2)
# Out:
#    Id             Tag
# 0  80            flex
# 1  80  actionscript 3

# %%
top_k_tags = tags['Tag'].value_counts()[:K].index.to_list()
top_k_tags
# Out:
# ['javascript',
#  'java',
#  'c#',
#  'php',
#  'android',
#  'jquery',
#  'python',
#  'html',
#  'c++',
#  'ios',
#  'mysql',
#  'css',
#  'sql',
#  'asp.net',
#  'objective c',
#  'ruby on rails',
#  '.net',
#  'c',
#  'iphone',
#  'angularjs']

# %%
tags = tags[tags['Tag'].isin(top_k_tags)]
print(tags.shape)
tags.head(2)
# Out:
# (1119155, 2)
#     Id      Tag
# 7  120      sql
# 8  120  asp.net

# %%
tags = tags.groupby('Id').apply(lambda x: x['Tag'].values).reset_index(name='Tags')
tags.head(2)
# Out:
#     Id            Tags
# 0  120  [sql, asp.net]
# 1  260      [c#, .net]

# %%
tags['Tags'] = tags['Tags'].apply(lambda x: ','.join(x))
tags.head(2)
# Out:
#     Id         Tags
# 0  120  sql,asp.net
# 1  260      c#,.net

# %%
dataset = pd.merge(questions, tags, on=['Id'], how='right')
del questions, tags
dataset.head()
# Out:
#     Id  ...         Tags
# 0  120  ...  sql,asp.net
# 1  260  ...      c#,.net
# 2  330  ...          c++
# 3  470  ...         .net
# 4  650  ...           c#
#
# [5 rows x 8 columns]

# %%
dataset = dataset.loc[:, ('Title', 'Body', 'Tags')]
dataset.head()
# Out:
#                                                Title  ...         Tags
# 0                                  ASP.NET Site Maps  ...  sql,asp.net
# 1  Adding scripting functionality to .NET applica...  ...      c#,.net
# 2          Should I use nested classes in this case?  ...          c++
# 3              Homegrown consumption of web services  ...         .net
# 4                Automatically update version number  ...           c#
#
# [5 rows x 3 columns]

# %%
dataset.iloc[0]['Title'], dataset.iloc[0]['Body']
# Out:
# ('ASP.NET Site Maps',
#  "<p>Has anyone got experience creating <strong>SQL-based ASP.NET</strong> site-map providers?</p>\n\n<p>I've got the default XML file <code>web.sitemap</code> working properly with my Menu and <strong>SiteMapPath</strong> controls, but I'll need a way for the users of my site to create and modify pages dynamically.</p>\n\n<p>I need to tie page viewing permissions into the standard <code>ASP.NET</code> membership system as well.</p>\n")

# %%
def parse_html(col):
    soup = bs.BeautifulSoup(col,'lxml').body
    text = re.sub('<.+?>', ' ', str(soup))
    text = re.sub('\n', ' ', text)
    text = re.sub('\s{2,}', ' ', text)
    text = text.strip()
    return text

# %%
dataset['parsed_body'] = dataset['Body'].apply(parse_html)

# %%
dataset.head()
# Out:
#                                                Title  ...                                        parsed_body
# 0                                  ASP.NET Site Maps  ...  Has anyone got experience creating SQL-based A...
# 1  Adding scripting functionality to .NET applica...  ...  I have a little game written in C#. It uses a ...
# 2          Should I use nested classes in this case?  ...  I am working on a collection of classes used f...
# 3              Homegrown consumption of web services  ...  I've been writing a few web services for a .ne...
# 4                Automatically update version number  ...  I would like the version property of my applic...
#
# [5 rows x 4 columns]

# %%
dataset['new_body'] = dataset['Title'] + ' ' + dataset['parsed_body']
dataset.head()
# Out:
#                                                Title  ...                                           new_body
# 0                                  ASP.NET Site Maps  ...  ASP.NET Site Maps Has anyone got experience cr...
# 1  Adding scripting functionality to .NET applica...  ...  Adding scripting functionality to .NET applica...
# 2          Should I use nested classes in this case?  ...  Should I use nested classes in this case? I am...
# 3              Homegrown consumption of web services  ...  Homegrown consumption of web services I've bee...
# 4                Automatically update version number  ...  Automatically update version number I would li...
#
# [5 rows x 5 columns]

# %%
dataset = dataset.loc[:, ('new_body', 'Tags')]
dataset.columns = ['Body', 'Tags']
dataset.head()
# Out:
#                                                 Body         Tags
# 0  ASP.NET Site Maps Has anyone got experience cr...  sql,asp.net
# 1  Adding scripting functionality to .NET applica...      c#,.net
# 2  Should I use nested classes in this case? I am...          c++
# 3  Homegrown consumption of web services I've bee...         .net
# 4  Automatically update version number I would li...           c#

# %%
dataset['Body'] = dataset['Body'].str.lower()
dataset.head()
# Out:
#                                                 Body         Tags
# 0  asp.net site maps has anyone got experience cr...  sql,asp.net
# 1  adding scripting functionality to .net applica...      c#,.net
# 2  should i use nested classes in this case? i am...          c++
# 3  homegrown consumption of web services i've bee...         .net
# 4  automatically update version number i would li...           c#

# %%
dataset.to_csv('processed_data.csv', index=False)
with open('top_k_tags.pkl', 'wb') as f:
    pickle.dump(top_k_tags, f)
